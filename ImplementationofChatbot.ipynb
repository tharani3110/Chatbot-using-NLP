# %% [markdown]
# # Implementation of chatbot using NLP

# %%
pip install nltk scikit-learn streamlit
# Out:
# Requirement already satisfied: nltk in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (3.9.1)
# Requirement already satisfied: scikit-learn in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (1.6.1)
# Requirement already satisfied: streamlit in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (1.42.2)
# Requirement already satisfied: click in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: packaging<25,>=20 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (19.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (1.28.0)
# Requirement already satisfied: colorama in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.19.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.23.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\m.r.n.bavatharani\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing necessary libraries
import nltk
import random
import os
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl._create_default_https_context = ssl._create_unverified_context
nltk.data.path.append(os.path.abspath('nltk_data'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\M.R.N.BAVATHARANI\AppData\Roaming\nltk_data..
# [nltk_data]     .
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
intents = [
    {
        "tag": "greeting",
        "patterns": ["Hi", "Hello", "Hey", "Whats up", "How are you"],
        "responses": ["Hi there", "Hello", "Hey", "Nothing much", "I'm fine, thank you"]
    },
    {
        "tag": "goodbye",
        "patterns": ["Bye", "See you later", "Goodbye", "Take care"],
        "responses": ["Goodbye", "See you later", "Take care"]
    },
    {
        "tag": "thanks",
        "patterns": ["Thank you", "Thanks", "Thanks a lot", "I appreciate it"],
        "responses": ["You're welcome", "No problem", "Glad I could help"]
    },
    {
        "tag": "about",
        "patterns": ["What can you do", "Who are you", "What are you", "What is your purpose"],
        "responses": ["I am a chatbot", "My purpose is to assist you", "I can answer questions and provide assistance"]
    },
    {
        "tag": "help",
        "patterns": ["Help", "I need help", "Can you help me", "What should I do"],
        "responses": ["Sure, what do you need help with?", "I'm here to help. What's the problem?", "How can I assist you?"]
    },
    {
        "tag": "age",
        "patterns": ["How old are you", "What's your age"],
        "responses": ["I don't have an age. I'm a chatbot.", "I was just born in the digital world.", "Age is just a number for me."]
    },
    {
        "tag": "weather",
        "patterns": ["What's the weather like", "How's the weather today"],
        "responses": ["I'm sorry, I cannot provide real-time weather information.", "You can check the weather on a weather app or website."]
    },
    {
        "tag": "budget",
        "patterns": ["How can I make a budget", "What's a good budgeting strategy", "How do I create a budget"],
        "responses": [
            "To make a budget, start by tracking your income and expenses. Then, allocate your income towards essential expenses like rent, food, and bills. Next, allocate some of your income towards savings and debt repayment. Finally, allocate the remainder of your income towards discretionary expenses like entertainment and hobbies.",
            "A good budgeting strategy is to use the 50/30/20 rule. This means allocating 50% of your income towards essential expenses, 30% towards discretionary expenses, and 20% towards savings and debt repayment.",
            "To create a budget, start by setting financial goals for yourself. Then, track your income and expenses for a few months to get a sense of where your money is going. Next, create a budget by allocating your income towards essential expenses, savings and debt repayment, and discretionary expenses."
        ]
    },
    {
        "tag": "credit_score",
        "patterns": ["What is a credit score", "How do I check my credit score", "How can I improve my credit score"],
        "responses": [
            "A credit score is a number that represents your creditworthiness. It is based on your credit history and is used by lenders to determine whether or not to lend you money. The higher your credit score, the more likely you are to be approved for credit.",
            "You can check your credit score for free on several websites such as Credit Karma and Credit Sesame.",
            "To improve your credit score, pay your bills on time, reduce your debt, avoid applying for too much new credit, and maintain a good credit history."
        ]
    },
    {
        "tag": "food_recommendations",
        "patterns": ["What should I eat?", "Recommend me a meal", "I need a food suggestion"],
        "responses": [
            "How about trying a healthy salad with grilled chicken?",
            "If you're in the mood for comfort food, maybe a bowl of pasta?",
            "A smoothie bowl with fresh fruits could be a great option!",
            "Why not go for sushi or a hearty sandwich?"
        ]
    },
    {
        "tag": "fitness_tips",
        "patterns": ["How can I stay fit?", "Give me some fitness tips", "What's the best way to exercise?"],
        "responses": [
            "Stay consistent with a mix of cardio and strength training.",
            "Try to get at least 30 minutes of physical activity daily.",
            "Don't forget to warm up before exercising and stretch after.",
            "Eating a balanced diet and staying hydrated are key to staying fit."
        ]
    }
]

# %%
# Create the vectorizer and classifier
vectorizer = TfidfVectorizer()
clf = LogisticRegression(random_state=0, max_iter=10000)

#Preprocess the data
tags = []
patterns = []
for intent in intents:
    for pattern in intent['patterns']:
        tags.append(intent['tag'])
        patterns.append(pattern)

# %%
# Training the model
x = vectorizer.fit_transform(patterns)
y = tags
clf.fit(x, y)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
# Python function to chat with the chatbot
def chatbot(input_text):
    input_text = vectorizer.transform([input_text])
    tag = clf.predict(input_text)[0]
    for intent in intents:
        if intent['tag'] == tag:
            response = random.choice(intent['responses'])
            return response

# %%
# Checking our chatbot.
user_input = "What's your age?"
response = chatbot(user_input)
print(response)
# Out:
# My purpose is to assist you

# %%
user_input = "Hello"
response = chatbot(user_input)
print(response)
# Out:
# I'm fine, thank you

# %%
user_input = "budget"
response = chatbot(user_input)
print(response)
# Out:
# To create a budget, start by setting financial goals for yourself. Then, track your income and expenses for a few months to get a sense of where your money is going. Next, create a budget by allocating your income towards essential expenses, savings and debt repayment, and discretionary expenses.

# %%
user_input = "hi"
response = chatbot(user_input)
print(response)
# Out:
# Hi there

# %%
user_input = "How's the weather today"
response = chatbot(user_input)
print(response)
# Out:
# You can check the weather on a weather app or website.
